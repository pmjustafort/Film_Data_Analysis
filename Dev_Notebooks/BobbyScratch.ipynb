# %%
import pandas as pd
import gzip
import numpy as np
import sqlite3
import datetime
import json
import requests

# %% [markdown]
# ## Business Problem
#
# In the history of the cinematography industry, remarkable movies such as 'Avatar' (2009), 'Avengers: Endgame' (2019), 'Titanic' (1997), among others, have achieved tremendous success, captivating global audiences and redefining filmmaking. However, in the last years and amplified by the impact of the COVID-19 pandemic, the industry has faced significant disruptions due to the surge in popular streaming services like Netflix, Amazon Prime Video, Disney+, Tubi (which is free), Hulu, and others. As a result, producing a movie that attracts audiences to cinemas has become more challenging than ever before. Creating a successful film today requires unprecedented rigor and adaptation to the changing landscape of movie consumption.

# %%
conn = sqlite3.Connection("../Data/im.db")
df_bom_movie_gross = pd.read_csv("../Data/bom.movie_gross.csv")
df_tn_movie_budgets = pd.read_csv("../Data/tn.movie_budgets.csv")
df_tmdb_movies = pd.read_csv("../Data/tmdb.movies.csv")
df_rt_movie_info = pd.read_csv("../Data/rt.movie_info.tsv",delimiter='\t')
df_rt_reviews = pd.read_csv("../Data/rt.reviews.tsv",delimiter='\t', encoding='latin1')
query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = conn.execute(query).fetchall()
cur = conn.cursor()

# %%
df_tn_movie_budgets.loc[df_tn_movie_budgets.production_budget.str.len()> 11 ]
# Out:
#      id  release_date                                        movie  \
# 0     1  Dec 18, 2009                                       Avatar
# 1     2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2     3   Jun 7, 2019                                 Dark Phoenix
# 3     4   May 1, 2015                      Avengers: Age of Ultron
# 4     5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ..   ..           ...                                          ...
# 401   2  Apr 18, 2014                                Transcendence
# 402   3  Feb 18, 2005                              Son of the Mask
# 403   4  Dec 14, 2018                               Mortal Engines
# 404   5  Aug 16, 2002                 The Adventures of Pluto Nash
# 405   6  Jan 20, 2012                      Jin lÃ­ng shÃ­ san chai
#
#     production_budget domestic_gross worldwide_gross
# 0        $425,000,000   $760,507,625  $2,776,345,279
# 1        $410,600,000   $241,063,875  $1,045,663,875
# 2        $350,000,000    $42,762,350    $149,762,350
# 3        $330,600,000   $459,005,868  $1,403,013,963
# 4        $317,000,000   $620,181,382  $1,316,721,747
# ..                ...            ...             ...
# 401      $100,000,000    $23,022,309    $103,039,258
# 402      $100,000,000    $17,018,422     $59,918,422
# 403      $100,000,000    $15,951,040     $85,287,417
# 404      $100,000,000     $4,411,102      $7,094,995
# 405      $100,000,000       $311,434     $98,227,017
#
# [406 rows x 6 columns]

# %%
url = "https://api.themoviedb.org/3/genre/movie/list?language=en"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwYTNlZTFhNDUyYTkwZWQ2OWIwNjMzNDBhZjlhZjFkOCIsInN1YiI6IjY0Y2FiYmUzNDNjZDU0MDExYzhjZTQwMyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.PUiNT5UDbCjZYIyCUDQzPJiQ3nERUW3LBUCqBz0oUEU"
}

response = requests.get(url, headers=headers)

genre_id_dict = json.loads(response.text)
genre_id_dicts = genre_id_dict["genres"]
df_tmdb_movies['genres'] = ''

# %%
for genre_id in genre_id_dicts:
    df_tmdb_movies.loc[df_tmdb_movies['genre_ids'].str.contains(str(genre_id['id'])), 
                       'genres'] = df_tmdb_movies['genres'] + genre_id['name'] + ","
df_tmdb_movies['genres'] = df_tmdb_movies['genres'].str.strip(',')

# %%
df_tmdb_movies['genres'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26512    False
# 26513    False
# 26514    False
# 26515    False
# 26516    False
# Name: genres, Length: 26517, dtype: bool

# %%
df_tmdb_movies['genres'] = df_tmdb_movies['genres'].apply(lambda x: x.split(','))

# %%
df_movies = pd.read_sql_query( 
"""
SELECT movie_id, b.primary_title AS title, b.start_year AS year, b.runtime_minutes, b.genres,
    r.averagerating, r.numvotes, group_concat(DISTINCT primary_name) AS directors, 
    group_concat(DISTINCT person_id) AS director_ids
FROM movie_basics AS b
    JOIN movie_ratings AS r
    USING (movie_id)
    JOIN directors AS d
    USING (movie_id)
    JOIN persons AS p
    USING (person_id)
GROUP BY movie_id
"""
, conn)

# %% [markdown]
# ## Cleaning Year Data
#     - tn_movie_budgets
#     - bom_movie_gross
#     - df_tmdb_movies

# %%
#Cleaning Year Data
# tn_movie_budgets
df_tn_movie_budgets['release_date'] = pd.to_datetime(df_tn_movie_budgets['release_date'], errors = 'coerce')
df_tn_movie_budgets['year'] = df_tn_movie_budgets['release_date'].dt.strftime('%Y').astype(int)
# tmdb_movies
df_tmdb_movies['release_date'] = pd.to_datetime(df_tmdb_movies['release_date'], errors = 'coerce')
df_tmdb_movies['year'] = df_tmdb_movies['release_date'].dt.strftime('%Y').astype(int)

# %% [markdown]
# ## Cleaning Boxoffice Data
#     - tn_movie_budgets
#     - bom_movie_gross
#     - df_tmdb_movies

# %%
# tn_movie_budgets
df_tn_movie_budgets['worldwide_gross'] = df_tn_movie_budgets['worldwide_gross'].apply(lambda x: float(str(x).strip().replace('$','').replace(',','')))
df_tn_movie_budgets['production_budget'] = df_tn_movie_budgets['production_budget'].apply(lambda x: float(str(x).strip().replace('$','').replace(',','')))
df_tn_movie_budgets.rename(columns={'worldwide_gross': 'gross'},inplace = True)
# bom_movie_gross
df_bom_movie_gross['foreign_gross'] = df_bom_movie_gross['foreign_gross'].apply(lambda x: float(str(x).strip().replace('$','').replace(',','')))
df_bom_movie_gross['gross'] = df_bom_movie_gross['domestic_gross'] + df_bom_movie_gross['foreign_gross']

# %%
df_tn_movie_budgets.production_budget.max()
# Out:
# 425000000.0

# %% [markdown]
# ## Renaming columns for merge
#     - tn_movie_budgets
#     - bom_movie_gross
#     - df_tmdb_movies

# %%
df_tn_movie_budgets.rename(columns={'movie': 'title'},inplace = True)

# %%
df_movies.dropna(subset=['genres'],inplace = True)

# %%
df_movies['genres'] = df_movies['genres'].apply(lambda x: x.split(','))

# %% [markdown]
# ## Merging DFs

# %%
df_movies_merged 
df_bom_movie_gross
df_tn_movie_budgets
df_tmdb_movies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e7062766772c> in <module>
# ----> 1 df_movies_merged
#       2 df_bom_movie_gross
#       3 df_tn_movie_budgets
#       4 df_tmdb_movies
#
# NameError: name 'df_movies_merged' is not defined

# %%
df_movies_merged = df_movies.merge(df_bom_movie_gross[['title', 'studio', 'gross','year']],
                                          on = ['title','year'], how='left')

# %%
df_movies_merged2 = df_movies_merged.merge(df_tn_movie_budgets[['title', "production_budget", 
                                                                "gross", 'year']], on = ['title','year'], how='outer')

# %%
df_movies_merged3 = df_movies_merged2.merge(df_tmdb_movies[['title', "genres", 'year','vote_count', 'vote_average',
                                                            'release_date']], on = ['title','year'], how='left')

# %%
dfmean = df_movies_merged3[['gross_x', 'gross_y']].copy()
df_movies_merged3['gross'] = dfmean.mean(axis=1)

# %%
dfmean = df_movies_merged3[['gross_x', 'gross_y','gross']].copy()
dfmean.dropna(subset = ['gross'])
# Out:
#            gross_x       gross_y         gross
# 16             NaN  7.370600e+04  7.370600e+04
# 36       8744000.0           NaN  8.744000e+06
# 42     188100000.0  1.878612e+08  1.879806e+08
# 46      53200000.0  6.210859e+07  5.765429e+07
# 47     652301019.4  1.648855e+09  1.150578e+09
# ...            ...           ...           ...
# 77367          NaN  0.000000e+00  0.000000e+00
# 77368          NaN  2.404950e+05  2.404950e+05
# 77369          NaN  1.338000e+03  1.338000e+03
# 77370          NaN  0.000000e+00  0.000000e+00
# 77371          NaN  1.810410e+05  1.810410e+05
#
# [6316 rows x 3 columns]

# %%
score_a = 9.9
a_votes = 100
score_b = 0
b_votes = 0
total_votes = a_votes+b_votes
score = ((b_votes/total_votes)*score_b)+((a_votes/total_votes)*score_a)
score
# Out:
# 9.9

# %%
df_rating = df_movies_merged3[['vote_average','averagerating','vote_count','numvotes']].fillna(value = 0)

# %%
df_rating['total_votes'] = df_rating['vote_count']+ df_rating['numvotes']
df_rating['weighted_average_user_rating'] = ((df_rating['vote_count']/df_rating['total_votes'])*df_rating['vote_average'])+((df_rating['numvotes']/df_rating['total_votes'])*df_rating['averagerating'])

# %%
df_movies_merged3['weighted_average_user_rating'] = df_rating['weighted_average_user_rating']

# %%
df_movies_merged3[['weighted_average_user_rating','averagerating','vote_average']].sort_values('vote_average',ascending=False).head(50)
# Out:
#        weighted_average_user_rating  averagerating  vote_average
# 60937                      5.846667            5.8          10.0
# 55945                      7.109898            7.1          10.0
# 68507                      7.071429            7.0          10.0
# 24633                      6.173333            5.9          10.0
# 68553                      3.271579            3.2          10.0
# 47132                      8.625000            8.5          10.0
# 24375                      7.022901            7.0          10.0
# 68627                      7.226087            7.1          10.0
# 68633                      8.409816            8.4          10.0
# 68643                      8.457143            8.2          10.0
# 24296                      7.413098            7.4          10.0
# 47098                      7.211538            7.1          10.0
# 68783                      8.500000            8.4          10.0
# 24246                      4.910638            4.8          10.0
# 46860                      8.666667            8.5          10.0
# 63282                      9.500602            9.5          10.0
# 9067                       7.922340            7.9          10.0
# 68926                      6.265517            6.2          10.0
# 46784                      4.426667            4.3          10.0
# 30921                      6.636364            6.3          10.0
# 30908                      7.832353            7.8          10.0
# 54991                      6.208910            6.2          10.0
# 47439                      8.525714            8.5          10.0
# 48032                      8.147500            8.1          10.0
# 48024                      6.940000            6.6          10.0
# 67543                      9.833333            9.8          10.0
# 54276                      7.825000            7.8          10.0
# 67594                      8.429630            8.4          10.0
# 17561                      4.454545            3.9          10.0
# 30350                      7.013333            6.8          10.0
# 54537                      4.537500            4.3          10.0
# 30787                      7.456522            7.4          10.0
# 67887                      9.019608            9.0          10.0
# 11324                      7.500000            7.0          10.0
# 54579                      7.207407            7.1          10.0
# 47314                      5.897674            5.8          10.0
# 47311                      5.378333            5.3          10.0
# 15706                      5.916667            5.8          10.0
# 24923                      8.307944            8.3          10.0
# 46783                      6.553191            6.4          10.0
# 69072                      8.033333            8.0          10.0
# 67532                      7.428571            7.0          10.0
# 24008                      6.040000            5.6          10.0
# 45368                      9.322581            9.3          10.0
# 27371                      7.326471            7.3          10.0
# 45224                      6.509091            6.4          10.0
# 69824                      8.520000            8.5          10.0
# 45143                      4.985714            4.8          10.0
# 56983                      9.030303            9.0          10.0
# 32054                      3.393056            3.3          10.0

# %%
df_movies_merged3
# Out:
#         movie_id                            title  year  runtime_minutes  \
# 0      tt0063540                        Sunghursh  2013            175.0
# 1      tt0066787  One Day Before the Rainy Season  2019            114.0
# 2      tt0069049       The Other Side of the Wind  2018            122.0
# 3      tt0069204                  Sabse Bada Sukh  2018              NaN
# 4      tt0100275         The Wandering Soap Opera  2017             80.0
# ...          ...                              ...   ...              ...
# 77367        NaN                           Red 11  2018              NaN
# 77368        NaN                        Following  1999              NaN
# 77369        NaN    Return to the Land of Wonders  2005              NaN
# 77370        NaN             A Plague So Pleasant  2015              NaN
# 77371        NaN                My Date With Drew  2005              NaN
#
#                        genres_x  averagerating  numvotes  \
# 0        [Action, Crime, Drama]            7.0      77.0
# 1            [Biography, Drama]            7.2      43.0
# 2                       [Drama]            6.9    4517.0
# 3               [Comedy, Drama]            6.1      13.0
# 4      [Comedy, Drama, Fantasy]            6.5     119.0
# ...                         ...            ...       ...
# 77367                       NaN            NaN       NaN
# 77368                       NaN            NaN       NaN
# 77369                       NaN            NaN       NaN
# 77370                       NaN            NaN       NaN
# 77371                       NaN            NaN       NaN
#
#                           directors         director_ids studio  gross_x  \
# 0               Harnam Singh Rawail            nm0712540    NaN      NaN
# 1                         Mani Kaul            nm0002411    NaN      NaN
# 2                      Orson Welles            nm0000080    NaN      NaN
# 3              Hrishikesh Mukherjee            nm0611531    NaN      NaN
# 4      Raoul Ruiz,Valeria Sarmiento  nm0749914,nm0765384    NaN      NaN
# ...                             ...                  ...    ...      ...
# 77367                           NaN                  NaN    NaN      NaN
# 77368                           NaN                  NaN    NaN      NaN
# 77369                           NaN                  NaN    NaN      NaN
# 77370                           NaN                  NaN    NaN      NaN
# 77371                           NaN                  NaN    NaN      NaN
#
#        production_budget   gross_y         genres_y  vote_count  vote_average  \
# 0                    NaN       NaN              NaN         NaN           NaN
# 1                    NaN       NaN              NaN         NaN           NaN
# 2                    NaN       NaN  [Comedy, Drama]        64.0           7.0
# 3                    NaN       NaN              NaN         NaN           NaN
# 4                    NaN       NaN              NaN         NaN           NaN
# ...                  ...       ...              ...         ...           ...
# 77367             7000.0       0.0              NaN         NaN           NaN
# 77368             6000.0  240495.0              NaN         NaN           NaN
# 77369             5000.0    1338.0              NaN         NaN           NaN
# 77370             1400.0       0.0              NaN         NaN           NaN
# 77371             1100.0  181041.0              NaN         NaN           NaN
#
#       release_date     gross  weighted_average_user_rating
# 0              NaT       NaN                      7.000000
# 1              NaT       NaN                      7.200000
# 2       2018-11-02       NaN                      6.901397
# 3              NaT       NaN                      6.100000
# 4              NaT       NaN                      6.500000
# ...            ...       ...                           ...
# 77367          NaT       0.0                           NaN
# 77368          NaT  240495.0                           NaN
# 77369          NaT    1338.0                           NaN
# 77370          NaT       0.0                           NaN
# 77371          NaT  181041.0                           NaN
#
# [77372 rows x 19 columns]

# %%
df_movies_merged5 = df_movies_merged3.drop(columns = ['vote_average','averagerating','vote_count','numvotes','director_ids','movie_id','studio','gross_x','gross_y'])

# %%
master_df = df_movies_merged5.dropna(subset = ['production_budget','weighted_average_user_rating','directors'])
# Out:
# pandas.core.frame.DataFrame

# %%
master_df.drop_duplicates(subset=['title'],inplace=True)
# Out:
# <ipython-input-151-f17ec1acb8d6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   master_df.drop_duplicates(subset=['title'],inplace=True)

# %%
master_df.loc[master_df['genres_x']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-167-a6d945179402> in <module>
# ----> 1 master_df.loc['Animation' in master_df['genres_x']]
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
# -> 3491             loc = self.index.get_loc(key)
#    3492
#    3493             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: False

# %%
genres = master_df.explode('genres_x')

# %%
genres['genres_x']
# Out:
# 16            Action
# 16         Animation
# 16            Comedy
# 42         Adventure
# 42            Comedy
#             ...
# 69511         Comedy
# 69511          Drama
# 70511    Documentary
# 71556      Biography
# 71556          Drama
# Name: genres_x, Length: 3745, dtype: object

# %%
genres.loc[genres['genres_x'] == 'Animation']
# Out:
#                                        title  year  runtime_minutes  \
# 16                                Foodfight!  2012             91.0
# 57                                   Tangled  2010            100.0
# 87                               Toy Story 3  2010            103.0
# 106                            Puss in Boots  2011             90.0
# 151                               The Smurfs  2011            103.0
# ...                                      ...   ...              ...
# 51082                           Peter Rabbit  2018             95.0
# 52024  Hotel Transylvania 3: Summer Vacation  2018             97.0
# 52817          Sgt. Stubby: An American Hero  2018             84.0
# 59475                              Smallfoot  2018             96.0
# 61176                            Wonder Park  2019             85.0
#
#         genres_x                       directors  production_budget  \
# 16     Animation               Lawrence Kasanoff         45000000.0
# 57     Animation       Byron Howard,Nathan Greno        260000000.0
# 87     Animation                     Lee Unkrich        200000000.0
# 106    Animation                    Chris Miller        130000000.0
# 151    Animation                    Raja Gosnell        110000000.0
# ...          ...                             ...                ...
# 51082  Animation                      Will Gluck         50000000.0
# 52024  Animation              Genndy Tartakovsky         65000000.0
# 52817  Animation                   Richard Lanni         25000000.0
# 59475  Animation  Karey Kirkpatrick,Jason Reisig         80000000.0
# 61176  Animation                     Dylan Brown        100000000.0
#
#                                                 genres_y release_date  \
# 16                                                   NaN          NaT
# 57                                   [Animation, Family]   2010-11-24
# 87                           [Animation, Comedy, Family]   2010-06-17
# 106    [Action, Adventure, Animation, Comedy, Family,...   2011-10-28
# 151      [Adventure, Animation, Comedy, Family, Fantasy]   2011-07-29
# ...                                                  ...          ...
# 51082                     [Adventure, Animation, Family]   2018-02-09
# 52024               [Animation, Comedy, Family, Fantasy]   2018-06-30
# 52817       [Adventure, Animation, Family, History, War]   2018-04-13
# 59475            [Adventure, Animation, Family, Fantasy]   2018-09-28
# 61176                                                NaN          NaT
#
#               gross  weighted_average_user_rating
# 16     7.370600e+04                      1.900000
# 57     5.891386e+08                      7.794844
# 87     1.067940e+09                      8.292754
# 106    5.549937e+08                      6.596835
# 151    5.637247e+08                      5.502650
# ...             ...                           ...
# 51082  3.492182e+08                      6.597724
# 52024  5.278400e+08                      6.319023
# 52817  3.645957e+06                      6.896353
# 59475  2.138956e+08                      6.697489
# 61176  1.151494e+08                      5.700000
#
# [101 rows x 10 columns]

# %%
genres.to_csv('genres.csv')

# %%
master_df.to_csv('output.csv')

# %%
df_movies_merged5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77372 entries, 0 to 77371
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         77372 non-null  object
#  1   year                          77372 non-null  int64
#  2   runtime_minutes               65862 non-null  float64
#  3   genres_x                      73011 non-null  object
#  4   directors                     73011 non-null  object
#  5   production_budget             5982 non-null   float64
#  6   genres_y                      12823 non-null  object
#  7   release_date                  12823 non-null  datetime64[ns]
#  8   gross                         6316 non-null   float64
#  9   weighted_average_user_rating  73298 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 9.0+ MB

# %%
df_small = df_movies_merged3.drop(columns = ['movie_id', 'director_ids', 'studio'])

# %%
df_movies_merged4['genres_x'].explode()
# Out:
# 0          Action,Crime,Drama
# 1             Biography,Drama
# 2                       Drama
# 3                Comedy,Drama
# 4        Comedy,Drama,Fantasy
#                  ...
# 73668             Documentary
# 73669             Documentary
# 73670            Drama,Family
# 73671             Documentary
# 73673             Documentary
# Name: genres_x, Length: 73011, dtype: object

# %%
df_movies_merged3.dropna(subset=['gross_y', 'averagerating', 'total_profit'])
# Out:
#         movie_id                            title  year  runtime_minutes  \
# 47     tt0359950  The Secret Life of Walter Mitty  2013            114.0
# 51     tt0365907      A Walk Among the Tombstones  2014            114.0
# 52     tt0369610                   Jurassic World  2015            124.0
# 54     tt0376136                    The Rum Diary  2011            119.0
# 59     tt0383010                The Three Stooges  2012             92.0
# ...          ...                              ...   ...              ...
# 66552  tt7388562          Paul, Apostle of Christ  2018            108.0
# 66624  tt7401588                   Instant Family  2018            118.0
# 67283  tt7535780                   The Great Wall  2017             72.0
# 68417  tt7784604                       Hereditary  2018            127.0
# 69077  tt7959026                         The Mule  2018            116.0
#
#                         genres_x  averagerating  numvotes  \
# 47        Adventure,Comedy,Drama            7.3  275300.0
# 51            Action,Crime,Drama            6.5  105116.0
# 52       Action,Adventure,Sci-Fi            7.0  539338.0
# 54                  Comedy,Drama            6.2   94787.0
# 59                 Comedy,Family            5.1   28570.0
# ...                          ...            ...       ...
# 66552  Adventure,Biography,Drama            6.7    5662.0
# 66624               Comedy,Drama            7.4   46728.0
# 67283                Documentary            6.5      24.0
# 68417       Drama,Horror,Mystery            7.3  151571.0
# 69077       Crime,Drama,Thriller            7.1   58955.0
#
#                            directors         director_ids  studio  \
# 47                       Ben Stiller            nm0001774     Fox
# 51                       Scott Frank            nm0291082    Uni.
# 52                   Colin Trevorrow            nm1119880    Uni.
# 54                    Bruce Robinson            nm0732430      FD
# 59     Bobby Farrelly,Peter Farrelly  nm0268370,nm0268380     Fox
# ...                              ...                  ...     ...
# 66552                   Andrew Hyatt            nm1358366  Affirm
# 66624                    Sean Anders            nm1890845    Par.
# 67283               Tadhg O'Sullivan            nm2738464    Uni.
# 68417                      Ari Aster            nm4170048     A24
# 69077                 Clint Eastwood            nm0000142      WB
#
#            gross_x  production_budget       gross_y  \
# 47     188100000.0         91000000.0  1.878612e+08
# 51      53200000.0         28000000.0  6.210859e+07
# 52     652301019.4        215000000.0  1.648855e+09
# 54      23900000.0         45000000.0  2.154473e+07
# 59      54800000.0         30000000.0  5.405225e+07
# ...            ...                ...           ...
# 66552   23100000.0          5000000.0  2.552950e+07
# 66624  120600000.0         48000000.0  1.197362e+08
# 67283  334900000.0        150000000.0  3.344869e+08
# 68417   79400000.0         10000000.0  7.013390e+07
# 69077  172500000.0         50000000.0  1.708577e+08
#
#                                         genres_y  vote_count  vote_average  \
# 47                Adventure,Comedy,Drama,Fantasy      4859.0           7.1
# 51                  Crime,Drama,Mystery,Thriller      1685.0           6.3
# 52     Action,Adventure,Science Fiction,Thriller     14056.0           6.6
# 54                                  Comedy,Drama       652.0           5.7
# 59                                        Comedy       215.0           5.1
# ...                                          ...         ...           ...
# 66552                                    History        98.0           7.1
# 66624                               Comedy,Drama       782.0           7.6
# 67283                   Action,Adventure,Fantasy      2775.0           5.8
# 68417                    Horror,Mystery,Thriller      2491.0           7.0
# 69077                       Crime,Drama,Thriller      1584.0           6.5
#
#       release_date   gross_diff
# 47      2013-12-25     238817.0
# 51      2014-09-19   -8908587.0
# 52      2015-06-12 -996553844.6
# 54      2011-10-27    2355268.0
# 59      2012-04-13     747751.0
# ...            ...          ...
# 66552   2018-03-28   -2429498.0
# 66624   2018-11-16     863812.0
# 67283   2017-02-17     413148.0
# 68417   2018-06-08    9266095.0
# 69077   2018-12-14    1642324.0
#
# [1017 rows x 18 columns]

# %%
df_movies_merged3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78035 entries, 0 to 78034
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           73674 non-null  object
#  1   title              78035 non-null  object
#  2   year               78035 non-null  int64
#  3   runtime_minutes    66318 non-null  float64
#  4   genres_x           73011 non-null  object
#  5   averagerating      73674 non-null  float64
#  6   numvotes           73674 non-null  float64
#  7   directors          73674 non-null  object
#  8   director_ids       73674 non-null  object
#  9   studio             1979 non-null   object
#  10  gross_x            1363 non-null   float64
#  11  production_budget  5984 non-null   float64
#  12  gross_y            5984 non-null   float64
#  13  genres_y           12850 non-null  object
#  14  vote_count         12850 non-null  float64
#  15  vote_average       12850 non-null  float64
#  16  release_date       12850 non-null  datetime64[ns]
#  17  gross_diff         1028 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(7)
# memory usage: 11.3+ MB

# %%
df_gross = df_movies_merged3.loc[df_movies_merged3['gross_diff'].notna()]

# %%
df_gross.drop(df_gross[abs(df_gross['gross_diff']) <= 1000000].index, inplace = True)
df_gross
# Out:
# C:\Users\rober\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         movie_id                        title  year  runtime_minutes  \
# 51     tt0365907  A Walk Among the Tombstones  2014            114.0
# 52     tt0369610               Jurassic World  2015            124.0
# 54     tt0376136                The Rum Diary  2011            119.0
# 62     tt0398286                      Tangled  2010            100.0
# 64     tt0401729                  John Carter  2012            132.0
# ...          ...                          ...   ...              ...
# 64514  tt6966692                   Green Book  2018            130.0
# 65320  tt7137380                    Destroyer  2018            121.0
# 66552  tt7388562      Paul, Apostle of Christ  2018            108.0
# 68417  tt7784604                   Hereditary  2018            127.0
# 69077  tt7959026                     The Mule  2018            116.0
#
#                          genres_x  averagerating  numvotes  \
# 51             Action,Crime,Drama            6.5  105116.0
# 52        Action,Adventure,Sci-Fi            7.0  539338.0
# 54                   Comedy,Drama            6.2   94787.0
# 62     Adventure,Animation,Comedy            7.8  366366.0
# 64        Action,Adventure,Sci-Fi            6.6  241792.0
# ...                           ...            ...       ...
# 64514      Biography,Comedy,Drama            8.3  204972.0
# 65320          Action,Crime,Drama            6.2   13683.0
# 66552   Adventure,Biography,Drama            6.7    5662.0
# 68417        Drama,Horror,Mystery            7.3  151571.0
# 69077        Crime,Drama,Thriller            7.1   58955.0
#
#                        directors         director_ids     studio      gross_x  \
# 51                   Scott Frank            nm0291082       Uni.   53200000.0
# 52               Colin Trevorrow            nm1119880       Uni.  652301019.4
# 54                Bruce Robinson            nm0732430         FD   23900000.0
# 62     Byron Howard,Nathan Greno  nm0397174,nm1977355         BV  591800000.0
# 64                Andrew Stanton            nm0004056         BV  284200000.0
# ...                          ...                  ...        ...          ...
# 64514             Peter Farrelly            nm0268380       Uni.  319800000.0
# 65320               Karyn Kusama            nm0476201  Annapurna    5500000.0
# 66552               Andrew Hyatt            nm1358366     Affirm   23100000.0
# 68417                  Ari Aster            nm4170048        A24   79400000.0
# 69077             Clint Eastwood            nm0000142         WB  172500000.0
#
#        production_budget       gross_y  \
# 51            28000000.0  6.210859e+07
# 52           215000000.0  1.648855e+09
# 54            45000000.0  2.154473e+07
# 62           260000000.0  5.864772e+08
# 64           275000000.0  2.827781e+08
# ...                  ...           ...
# 64514         23000000.0  3.220344e+08
# 65320          9000000.0  3.681096e+06
# 66552          5000000.0  2.552950e+07
# 68417         10000000.0  7.013390e+07
# 69077         50000000.0  1.708577e+08
#
#                                         genres_y  vote_count  vote_average  \
# 51                  Crime,Drama,Mystery,Thriller      1685.0           6.3
# 52     Action,Adventure,Science Fiction,Thriller     14056.0           6.6
# 54                                  Comedy,Drama       652.0           5.7
# 62                              Animation,Family      6407.0           7.5
# 64              Action,Adventure,Science Fiction      3338.0           6.1
# ...                                          ...         ...           ...
# 64514                               Comedy,Drama      3499.0           8.3
# 65320                Action,Crime,Drama,Thriller       176.0           5.9
# 66552                                    History        98.0           7.1
# 68417                    Horror,Mystery,Thriller      2491.0           7.0
# 69077                       Crime,Drama,Thriller      1584.0           6.5
#
#       release_date   gross_diff
# 51      2014-09-19   -8908587.0
# 52      2015-06-12 -996553844.6
# 54      2011-10-27    2355268.0
# 62      2010-11-24    5322760.0
# 64      2012-03-09    1421900.0
# ...            ...          ...
# 64514   2018-11-16   -2234439.0
# 65320   2018-12-25    1818904.0
# 66552   2018-03-28   -2429498.0
# 68417   2018-06-08    9266095.0
# 69077   2018-12-14    1642324.0
#
# [583 rows x 18 columns]

# %%
# # Normalizing titles

# master_df['title'] = master_df['title'].apply(lambda title: title.lower().strip())
# df_bom_movie_gross['title'] = df_bom_movie_gross['title'].apply(lambda title: title.lower().strip())
# df_bom_movie_gross['domestic_gross'] = df_bom_movie_gross['domestic_gross'].apply(
#     lambda gross: float(str(gross).strip().replace(',', ''))
# )
# df_bom_movie_gross['foreign_gross'] = df_bom_movie_gross['foreign_gross'].apply(
#     lambda gross: float(str(gross).strip().replace(',', ''))
# )


# # Merging master dataframe with box office dataframe.

# master_df = master_df.merge(df_bom_movie_gross[['title', 'studio', 'domestic_gross', 'foreign_gross']], on='title', how='left')

# Converting gross values to floats.

# master_df['domestic_gross'] = master_df['domestic_gross'].apply(lambda x: float(str(x).strip().replace(',', '')))
# master_df['foreign_gross'] = master_df['foreign_gross'].apply(lambda x: float(str(x).strip().replace(',', '')))

# Prepping movie budgets dataframe to merge with master dataframe.

budgets = df_tn_movie_budgets.drop(columns=['production_budget', 'domestic_gross', 'worldwide_gross']).copy()

budgets[['production_budget', 'domestic_gross', 'worldwide_gross']] = df_tn_movie_budgets[
    ['production_budget', 'domestic_gross', 'worldwide_gross']
].applymap(
    lambda x: x.strip().replace('$', '').replace(',', '')
).astype('float').values

budgets['foreign_gross'] = budgets['worldwide_gross'] - budgets['domestic_gross']
budgets = budgets.drop(columns='worldwide_gross')
budgets = budgets.rename(columns={'movie': 'title'})
budgets['title'] = budgets['title'].apply(lambda title: title.lower().strip())

budgets = budgets.merge(df_bom_movie_gross[['title', 'studio', 'domestic_gross', 'foreign_gross']], on=['title', 'domestic_gross', 'foreign_gross'], how='left')

# Merging master dataframe with budgets dataframe
master_df

# domestic_growth_ = master_df['domestic_gross'].fillna(0)
# foreign_growth_ = master_df['foreign_gross'].fillna(0)
# master_df['total_gross'] = domestic_growth_ + foreign_growth_
# master_df.total_gross.value_counts()
# master_df['total_gross'] = master_df['total_gross'].replace(0, np.nan)
# master_df_ = master_df.dropna(subset=['total_gross', 'averagerating', 'total_profit'])
# master_df_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-12ce6087a67c> in <module>
#      35 budgets['title'] = budgets['title'].apply(lambda title: title.lower().strip())
#      36
# ---> 37 budgets = budgets.merge(df_bom_movie_gross[['title', 'studio', 'domestic_gross', 'foreign_gross']], on=['title', 'domestic_gross', 'foreign_gross'], how='left')
#      38
#      39 # Merging master dataframe with budgets dataframe
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     654         # validate the merge keys dtypes. We may need to coerce
#     655         # to avoid incompatible dtypes
# --> 656         self._maybe_coerce_merge_keys()
#     657
#     658         # If argument passed to validate,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1163                     inferred_right in string_types and inferred_left not in string_types
#    1164                 ):
# -> 1165                     raise ValueError(msg)
#    1166
#    1167             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on float64 and object columns. If you wish to proceed you should use pd.concat

# %%
b = budgets.set_index('title')
m = master_df.set_index('title')

# %%
pd.concat([b, m], axis=0).reset_index()

# %%
budgets

# %%
a = master_df.copy()
a.merge(budgets[['title', 'domestic_gross', 'foreign_gross']], on=)

# %%
budgets

# %%
['title', 'production_budget', 'domestic_gross', 'foreign_gross', 'studio']

# %%
master_df.production_budget.sum()

# %%
from sklearn.linear_model import LinearRegression

# %%
X = master_df_['averagerating'].values
y = master_df_['total_gross'].values

# %%
LinearRegression
